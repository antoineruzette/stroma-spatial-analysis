# %% [markdown]
# Authors: Antoine A. Ruzette, Simon F. Nørrelykke
# Date: 2024-07-21
#
# This notebook plots the correlation coefficients between cell pixel intensity and the signed distance to stroma for two partitions: inside a stromal region (distance < 0) and outside a stromal region (distance < 0) as defined by the modelled stromal border. It supports plotting results from parameter screens in QuPath.
#
# Contains the code to plot data from pNDRG1 images only.

# %%
import os
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from matplotlib.pyplot import ScalarFormatter

# colorblind-friendly colors
CB_palette = ['#377eb8', '#ff7f00', '#4daf4a',
                '#f781bf', '#a65628', '#984ea3',
                '#999999', '#e41a1c', '#dede00']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the columns you want to load
df_stroma = pd.read_csv('/Users/antoine/Harvard/IAC/NinaKozlova/20240119_SW1990_pNDRG1/Results/20240620_ML_RF_intensity_normalized/sensivity_stroma_annotation/SW shC Dox GEM  #1.vsi - 20x_DAPI, FITC, TRITC, CY5_01.csv', encoding='latin1')

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(12, 8))

# Plot data on each subplot
axs[0].scatter(df_stroma["pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='#377eb8', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[0].scatter(df_stroma["pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='#f781bf', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[0].axvline(x=0)
axs[0].legend()

axs[1].scatter(df_stroma["pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='#377eb8', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[1].scatter(df_stroma["pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='#f781bf', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[1].axvline(x=0)

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation', ha='center', va='center')
fig.text(-0.01, 0.75, 'Sigma', ha='center', va='center', rotation='vertical')
fig.text(-0.01, 0.28, 'FN_568 intensity', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the columns you want to load
df_stroma = pd.read_csv('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240216_pearson_correlations/AsPC LZ #2 GEM  Ker488 FN 568 pN 647 _01.vsi - 20x.csv')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot data on each subplot
axs[0, 0].scatter(df_stroma["pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[0, 0].scatter(df_stroma["pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[0, 0].axvline(x=0)
axs[0, 0].legend()

axs[0, 1].scatter(df_stroma["pearsonInsideStromaKer"], df_stroma[" sigma"], color='red', label='Inside KER_488', s=10, marker='*')
axs[0, 1].scatter(df_stroma["pearsonOutsideStromaKer"], df_stroma[" sigma"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[0, 1].axvline(x=0)
axs[0, 1].legend()

axs[1, 1].scatter(df_stroma["pearsonInsideStromaKer"], df_stroma["FN_568"], color='red', label='Inside KER_488', s=10, marker='*')
axs[1, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma["FN_568"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[1, 1].axvline(x=0)

axs[1, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[1, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[1, 0].axvline(x=0)

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation', ha='center', va='center')
fig.text(-0.01, 0.75, 'Sigma', ha='center', va='center', rotation='vertical')
fig.text(-0.01, 0.28, 'FN_568 intensity', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the columns you want to load
df_stroma = pd.read_csv('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240216_pearson_correlations/AsPC LZ #3 GEM  Ker488 FN 568 pN 647 _01.vsi - 20x.csv')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot data on each subplot
axs[0, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[0, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[0, 0].axvline(x=0)
axs[0, 0].legend()

axs[0, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma[" sigma"], color='red', label='Inside KER_488', s=10, marker='*')
axs[0, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma[" sigma"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[0, 1].axvline(x=0)
axs[0, 1].legend()

axs[1, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma["FN_568"], color='red', label='Inside KER_488', s=10, marker='*')
axs[1, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma["FN_568"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[1, 1].axvline(x=0)

axs[1, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[1, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[1, 0].axvline(x=0)

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation', ha='center', va='center')
fig.text(-0.01, 0.75, 'Sigma', ha='center', va='center', rotation='vertical')
fig.text(-0.01, 0.28, 'FN_568 intensity', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the columns you want to load
df_stroma = pd.read_csv('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240216_pearson_correlations/AsPC LZ #4 GEM  Ker488 FN 568 pN 647 _01.vsi - 20x.csv')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot data on each subplot
axs[0, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[0, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[0, 0].axvline(x=0)
axs[0, 0].legend()

axs[0, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma[" sigma"], color='red', label='Inside KER_488', s=10, marker='*')
axs[0, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma[" sigma"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[0, 1].axvline(x=0)
axs[0, 1].legend()

axs[1, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma["FN_568"], color='red', label='Inside KER_488', s=10, marker='*')
axs[1, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma["FN_568"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[1, 1].axvline(x=0)

axs[1, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[1, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[1, 0].axvline(x=0)

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation', ha='center', va='center')
fig.text(-0.01, 0.75, 'Sigma', ha='center', va='center', rotation='vertical')
fig.text(-0.01, 0.28, 'FN_568 intensity', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Specify the columns you want to load
df_stroma = pd.read_csv('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240216_pearson_correlations/AsPC LZ #5 GEM  Ker488 FN 568 pN 647 _01.vsi - 20x.csv')

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot data on each subplot
axs[0, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[0, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[0, 0].axvline(x=0)
axs[0, 0].legend()

axs[0, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma[" sigma"], color='red', label='Inside KER_488', s=10, marker='*')
axs[0, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma[" sigma"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[0, 1].axvline(x=0)
axs[0, 1].legend()

axs[1, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma["FN_568"], color='red', label='Inside KER_488', s=10, marker='*')
axs[1, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma["FN_568"], color='darkred', label='Outside KER_488', s=10, marker='o')
axs[1, 1].axvline(x=0)

axs[1, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='blue', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[1, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[1, 0].axvline(x=0)

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation', ha='center', va='center')
fig.text(-0.01, 0.75, 'Sigma', ha='center', va='center', rotation='vertical')
fig.text(-0.01, 0.28, 'FN_568 intensity', ha='center', va='center', rotation='vertical')

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240119_SW1990_pNDRG1/Results/20240620_ML_RF_intensity_normalized/sensivity_stroma_annotation'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 15))


# Plot data on each subplot
axs[0].scatter(df_stroma["pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='#377eb8', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[0].scatter(df_stroma["pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='#f781bf', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[0].axvline(x=0)
axs[0].legend()
axs[0].set_xlim(-0.25, 0.25)

axs[1].scatter(df_stroma["pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='#377eb8', label='Inside KER_488: pNDRG1_647', s=10, marker='*')
axs[1].scatter(df_stroma["pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='#f781bf', label='Outside KER_488: pNDRG1_647', s=10, marker='o')
axs[1].axvline(x=0)
axs[1].set_xlim(-0.25, 0.25)

'''
# Plot data on each subplot
axs[0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='lightblue', label='Outside KER_488: pNDRG1_647', s=20, marker='*')
axs[0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Inside KER_488: pNDRG1_647', s=20, marker='^')
# axs[0, 0].axvline(x=0, ls='--', color='black')
# axs[0, 0].legend(bbox_to_anchor=(.82, -0.1), fontsize='large')


axs[1].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Inside KER_488: pNDRG1_647', s=20, marker='^')
axs[1].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='lightblue', label='Outside KER_488: pNDRG1_647', s=20, marker='*')
# axs[1, 0].axvline(x=0, ls='--', color='black')'''

# Adjust the position of subplots to add space between rows
# axs[0, 0].set_position([axs[0, 0].get_position().x0, axs[0, 0].get_position().y0 - 0.03, axs[0, 0].get_position().width, axs[0, 0].get_position().height])
# axs[0, 1].set_position([axs[0, 1].get_position().x0, axs[0, 1].get_position().y0 - 0.03, axs[0, 1].get_position().width, axs[0, 1].get_position().height])

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation Coefficient', ha='center', va='center', fontsize=15)
fig.text(-0.01, 0.78, r'Smoothing sigma $\sigma$', ha='center', va='center', rotation='vertical', fontsize=15)
fig.text(-0.01, 0.23, 'FN_568 intensity', ha='center', va='center', rotation='vertical', fontsize=15)

plt.tight_layout()
# plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240222_plots/sensitivity_stroma_annotation.png', dpi=500, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
from scipy.stats import ttest_ind

# Select the data for the two groups
inside_KER488_pNDRG1_647 = df_stroma["pearsonInsideStromaKerPNDRG1"]
# Select the data for the two groups
outside_KER488_pNDRG1_647 = df_stroma["pearsonOutsideStromaKerPNDRG1"]

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488_pNDRG1_647, inside_KER488_pNDRG1_647)

# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488: pNDRG1_647 and Outside KER_488: pNDRG1_647: {:.2e}".format(p_value))
# Out:
# P-value for the difference in correlation coefficients between Inside KER_488: pNDRG1_647 and Outside KER_488: pNDRG1_647: 4.28e-31

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240119_SW1990_pNDRG1/Results/20240620_ML_RF_intensity_normalized/sensivity_stroma_annotation'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Group the data by 'sigma' and calculate the mean correlation
avg_corr_sigma = df_stroma.groupby(' sigma')[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()

# Group the data by 'FN_568' and calculate the mean correlation
avg_corr_FN_568 = df_stroma.groupby('FN_568')[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 15))

# Plot data on each subplot
axs[0].scatter(avg_corr_sigma["pearsonInsideStromaKerPNDRG1"], avg_corr_sigma.index, color='#377eb8', label='Cells inside stroma', s=100, marker='^')
axs[0].scatter(avg_corr_sigma["pearsonOutsideStromaKerPNDRG1"], avg_corr_sigma.index, color='#f781bf', label='Outside KER_488: pNDRG1_647', s=100, marker='o')
axs[0].axvline(x=0)
axs[0].legend()
axs[0].set_xlim(-0.1, 0.1)

axs[1].scatter(avg_corr_FN_568["pearsonInsideStromaKerPNDRG1"], avg_corr_FN_568.index, color='#377eb8', label='Inside KER_488: pNDRG1_647', s=100, marker='^')
axs[1].scatter(avg_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], avg_corr_FN_568.index, color='#f781bf', label='Outside KER_488: pNDRG1_647', s=100, marker='o')
axs[1].axvline(x=0)
axs[1].set_xlim(-0.1, 0.1)

# Set common labels
fig.text(0.5, -0.03, 'Median Pearson Correlation', ha='center', va='center', fontsize=25)
fig.text(-0.01, 0.75, r'Smoothing sigma $\sigma$', ha='center', va='center', rotation='vertical', fontsize=25)
fig.text(-0.01, 0.28, 'Signal intensity threshold, fibronectin', ha='center', va='center', rotation='vertical', fontsize=25)

plt.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240119_SW1990_pNDRG1/Results/20240620_ML_RF_intensity_normalized/sensivity_stroma_annotation'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Remove leading/trailing whitespace from column names
df_stroma.columns = df_stroma.columns.str.strip()

# Group the data by 'sigma' and calculate the mean and SEM of correlations
avg_corr_sigma = df_stroma.groupby('sigma')[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()
sem_corr_sigma = df_stroma.groupby('sigma')[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].sem()

# Group the data by 'FN_568' and calculate the mean and SEM of correlations
avg_corr_FN_568 = df_stroma.groupby('FN_568')[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()
sem_corr_FN_568 = df_stroma.groupby('FN_568')[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].sem()

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 15))

# Plot data on each subplot with error bars
axs[0].errorbar(avg_corr_sigma["pearsonInsideStromaKerPNDRG1"], avg_corr_sigma.index, xerr=sem_corr_sigma["pearsonInsideStromaKerPNDRG1"], fmt='^', color='#377eb8', label='Cells outside stroma', markersize=10, capsize=5)
axs[0].errorbar(avg_corr_sigma["pearsonOutsideStromaKerPNDRG1"], avg_corr_sigma.index, xerr=sem_corr_sigma["pearsonOutsideStromaKerPNDRG1"], fmt='o', color='#f781bf', label='Cells inside stroma', markersize=10, capsize=5)
axs[0].axvline(x=0)
axs[0].legend()
axs[0].set_xlim(-0.15, 0.1)

axs[1].errorbar(avg_corr_FN_568["pearsonInsideStromaKerPNDRG1"], avg_corr_FN_568.index, xerr=sem_corr_FN_568["pearsonInsideStromaKerPNDRG1"], fmt='^', color='#377eb8', label='Cells outside stroma', markersize=10, capsize=5)
axs[1].errorbar(avg_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], avg_corr_FN_568.index, xerr=sem_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], fmt='o', color='#f781bf', label='Cells inside stroma', markersize=10, capsize=5)
axs[1].axvline(x=0)
axs[1].set_xlim(-0.15, 0.1)

# Set common labels
fig.text(0.5, -0.03, 'Median Pearson Correlation', ha='center', va='center', fontsize=25)
fig.text(-0.01, 0.75, r'Smoothing sigma $\sigma$', ha='center', va='center', rotation='vertical', fontsize=25)
fig.text(-0.01, 0.28, 'Signal intensity threshold, fibronectin', ha='center', va='center', rotation='vertical', fontsize=25)

plt.tight_layout()
plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/Submission/Supplementary/figures/pNDRG1_sensitivity_stroma_annotation.png', dpi=300)
plt.show()

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

def bootstrap_sem(data, n_bootstrap=500):
    """Calculate the standard error of the median using bootstrapping."""
    medians = [data.sample(frac=1, replace=True).median() for _ in range(n_bootstrap)]
    return np.std(medians)

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240119_SW1990_pNDRG1/Results/20240620_ML_RF_intensity_normalized/sensivity_stroma_annotation'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Remove leading/trailing whitespace from column names
df_stroma.columns = df_stroma.columns.str.strip()

# Print the column names to check
print("Column names in the DataFrame after stripping whitespace:")
print(df_stroma.columns)

# Check if the required columns are present
required_columns = ['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']
for col in required_columns:
    if col not in df_stroma.columns:
        raise KeyError(f"Column {col} is not present in the DataFrame.")

# Group the data by 'sigma' and calculate the median
grouped_sigma = df_stroma.groupby('sigma')
avg_corr_sigma = grouped_sigma[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()

# Calculate the SEM for each group using bootstrapping
sem_corr_sigma = grouped_sigma.apply(lambda x: pd.Series({
    'pearsonInsideStromaKerPNDRG1': bootstrap_sem(x['pearsonInsideStromaKerPNDRG1']),
    'pearsonOutsideStromaKerPNDRG1': bootstrap_sem(x['pearsonOutsideStromaKerPNDRG1'])
}))

# Group the data by 'FN_568' and calculate the median
grouped_FN_568 = df_stroma.groupby('FN_568')
avg_corr_FN_568 = grouped_FN_568[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()

# Calculate the SEM for each group using bootstrapping
sem_corr_FN_568 = grouped_FN_568.apply(lambda x: pd.Series({
    'pearsonInsideStromaKerPNDRG1': bootstrap_sem(x['pearsonInsideStromaKerPNDRG1']),
    'pearsonOutsideStromaKerPNDRG1': bootstrap_sem(x['pearsonOutsideStromaKerPNDRG1'])
}))

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 15))

# Plot data on each subplot with error bars
axs[0].errorbar(avg_corr_sigma["pearsonInsideStromaKerPNDRG1"], avg_corr_sigma.index, xerr=sem_corr_sigma["pearsonInsideStromaKerPNDRG1"], fmt='^', color='#377eb8', label='Cells inside stroma', markersize=10, capsize=5)
axs[0].errorbar(avg_corr_sigma["pearsonOutsideStromaKerPNDRG1"], avg_corr_sigma.index, xerr=sem_corr_sigma["pearsonOutsideStromaKerPNDRG1"], fmt='o', color='#f781bf', label='Outside KER_488: pNDRG1_647', markersize=10, capsize=5)
axs[0].axvline(x=0)
axs[0].legend()
axs[0].set_xlim(-0.15, 0.1)

axs[1].errorbar(avg_corr_FN_568["pearsonInsideStromaKerPNDRG1"], avg_corr_FN_568.index, xerr=sem_corr_FN_568["pearsonInsideStromaKerPNDRG1"], fmt='^', color='#377eb8', label='Inside KER_488: pNDRG1_647', markersize=10, capsize=5)
axs[1].errorbar(avg_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], avg_corr_FN_568.index, xerr=sem_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], fmt='o', color='#f781bf', label='Outside KER_488: pNDRG1_647', markersize=10, capsize=5)
axs[1].axvline(x=0)
axs[1].set_xlim(-0.15, 0.1)

# Set the y-axis formatter to display scientific notation with a fixed number of decimals
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-2, 2))

for ax in axs:
    ax.yaxis.set_major_formatter(formatter)
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.tick_params(axis='both', which='minor', labelsize=20)
    ax.yaxis.get_offset_text().set_size(20)
    ax.yaxis.get_offset_text().set_fontsize(20)
    ax.yaxis.get_offset_text().set_color('black')

axs[0].set_ylabel(r'Smoothing sigma $\sigma$', fontsize=25)
axs[1].set_ylabel('Signal intensity threshold, fibronectin', fontsize=25)
axs[1].set_xlabel('Median Pearson Correlation', fontsize=25)
    

# Set common labels
'''fig.text(0.5, -0.03, 'Median Pearson Correlation', ha='center', va='center', fontsize=25)
fig.text(-0.01, 0.75, r'Smoothing sigma $\sigma$', ha='center', va='center', rotation='vertical', fontsize=25)
fig.text(-0.01, 0.26, 'Signal intensity threshold, fibronectin', ha='center', va='center', rotation='vertical', fontsize=25)
'''
plt.tight_layout()
plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/Submission/Supplementary/figures/pNDRG1_sensitivity_stroma_annotation.png', dpi=300)
plt.show()
# Out:
# Column names in the DataFrame after stripping whitespace:
# Index(['FN_568', 'sigma', 'pearsonInsideStromaKerPNDRG1',
#        'pearsonOutsideStromaKerPNDRG1', 'spearmanInsideStromaKerPNDRG1',
#        'spearmanOutsideStromaKerPNDRG1'],
#       dtype='object')
# /var/folders/3b/6sb_mkrj5jz7x94kf6pw1vmw0000gq/T/ipykernel_24567/3022631129.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sem_corr_sigma = grouped_sigma.apply(lambda x: pd.Series({
# ...

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

def bootstrap_sem(data, n_bootstrap=500):
    """Calculate the standard error of the median using bootstrapping."""
    medians = [data.sample(frac=1, replace=True).median() for _ in range(n_bootstrap)]
    return np.std(medians)

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240119_SW1990_pNDRG1/Results/20240620_ML_RF_intensity_normalized/sensivity_stroma_annotation'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Remove leading/trailing whitespace from column names
df_stroma.columns = df_stroma.columns.str.strip()

# Print the column names to check
print("Column names in the DataFrame after stripping whitespace:")
print(df_stroma.columns)

# Check if the required columns are present
required_columns = ['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']
for col in required_columns:
    if col not in df_stroma.columns:
        raise KeyError(f"Column {col} is not present in the DataFrame.")

# Group the data by 'sigma' and calculate the median
grouped_sigma = df_stroma.groupby('sigma')
avg_corr_sigma = grouped_sigma[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()

# Calculate the SEM for each group using bootstrapping
sem_corr_sigma = grouped_sigma.apply(lambda x: pd.Series({
    'pearsonInsideStromaKerPNDRG1': bootstrap_sem(x['pearsonInsideStromaKerPNDRG1']),
    'pearsonOutsideStromaKerPNDRG1': bootstrap_sem(x['pearsonOutsideStromaKerPNDRG1'])
}))

# Group the data by 'FN_568' and calculate the median
grouped_FN_568 = df_stroma.groupby('FN_568')
avg_corr_FN_568 = grouped_FN_568[['pearsonInsideStromaKerPNDRG1', 'pearsonOutsideStromaKerPNDRG1']].median()

# Calculate the SEM for each group using bootstrapping
sem_corr_FN_568 = grouped_FN_568.apply(lambda x: pd.Series({
    'pearsonInsideStromaKerPNDRG1': bootstrap_sem(x['pearsonInsideStromaKerPNDRG1']),
    'pearsonOutsideStromaKerPNDRG1': bootstrap_sem(x['pearsonOutsideStromaKerPNDRG1'])
}))

# Create the first plot for 'sigma'
fig1, ax1 = plt.subplots(figsize=(10, 10))

# Plot data on the first plot with error bars
ax1.errorbar(avg_corr_sigma["pearsonInsideStromaKerPNDRG1"], avg_corr_sigma.index, xerr=sem_corr_sigma["pearsonInsideStromaKerPNDRG1"], fmt='^', color='#377eb8', label='Inside stroma', markersize=10, capsize=5)
ax1.errorbar(avg_corr_sigma["pearsonOutsideStromaKerPNDRG1"], avg_corr_sigma.index, xerr=sem_corr_sigma["pearsonOutsideStromaKerPNDRG1"], fmt='o', color='#f781bf', label='Outside stroma', markersize=10, capsize=5)
ax1.axvline(x=0)
ax1.legend(prop={'size': 20})
ax1.set_xlim(-0.15, 0.1)

# Set the y-axis formatter to display scientific notation with a fixed number of decimals
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((-2, 2))
ax1.yaxis.set_major_formatter(formatter)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.tick_params(axis='both', which='minor', labelsize=20)
ax1.yaxis.get_offset_text().set_size(20)
ax1.yaxis.get_offset_text().set_fontsize(20)
ax1.yaxis.get_offset_text().set_color('black')

ax1.set_ylabel(r'Smoothing sigma $\sigma$', fontsize=25)
ax1.set_xlabel('Median Pearson Correlation', fontsize=25)

plt.tight_layout()
plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/Submission/Supplementary/figures/pNDRG1_sensitivity_stroma_annotation_sigma.png', dpi=300)
plt.show()

# Create the second plot for 'FN_568'
fig2, ax2 = plt.subplots(figsize=(10, 10))

# Plot data on the second plot with error bars
ax2.errorbar(avg_corr_FN_568["pearsonInsideStromaKerPNDRG1"], avg_corr_FN_568.index, xerr=sem_corr_FN_568["pearsonInsideStromaKerPNDRG1"], fmt='^', color='#377eb8', label='Inside stroma', markersize=10, capsize=5)
ax2.errorbar(avg_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], avg_corr_FN_568.index, xerr=sem_corr_FN_568["pearsonOutsideStromaKerPNDRG1"], fmt='o', color='#f781bf', label='Outside stroma', markersize=10, capsize=5)
ax2.axvline(x=0)
#ax2.legend(prop={'size': 20})
ax2.set_xlim(-0.15, 0.1)

# Set the y-axis formatter to display scientific notation with a fixed number of decimals
ax2.yaxis.set_major_formatter(formatter)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.tick_params(axis='both', which='minor', labelsize=20)
ax2.yaxis.get_offset_text().set_size(20)
ax2.yaxis.get_offset_text().set_fontsize(20)
ax2.yaxis.get_offset_text().set_color('black')

ax2.set_ylabel('Signal intensity threshold, fibronectin', fontsize=25)
ax2.set_xlabel('Median Pearson Correlation', fontsize=25)

plt.tight_layout()
plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/Submission/Supplementary/figures/pNDRG1_sensitivity_stroma_annotation_FN_568.png', dpi=300)
plt.show()
# Out:
# Column names in the DataFrame after stripping whitespace:
# Index(['FN_568', 'sigma', 'pearsonInsideStromaKerPNDRG1',
#        'pearsonOutsideStromaKerPNDRG1', 'spearmanInsideStromaKerPNDRG1',
#        'spearmanOutsideStromaKerPNDRG1'],
#       dtype='object')
# /var/folders/3b/6sb_mkrj5jz7x94kf6pw1vmw0000gq/T/ipykernel_24567/2156142665.py:46: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sem_corr_sigma = grouped_sigma.apply(lambda x: pd.Series({
# ...

# %% [markdown]
# ## Pearson and Spearman correlations

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240229_correlations/'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 15), sharex=True)

# Plot data on each subplot
axs[0, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma[" sigma"], color='lightblue', label='Outside KER_488: pNDRG1_647', s=20, marker='*')
axs[0, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Inside KER_488: pNDRG1_647', s=20, marker='^')
#axs[0, 0].axvline(x=0, ls='--', color='black')
axs[0, 0].legend(fontsize='large', loc='upper left')

axs[0, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma[" sigma"], color='lightgreen', label='Outside KER_488', s=20, marker='*')
axs[0, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma[" sigma"], color='darkgreen', label='Inside KER_488', s=20, marker='^')
#axs[0, 1].axvline(x=0, ls='--', color='black')
axs[0, 1].legend(fontsize='large', loc='upper right')

axs[1, 1].scatter(df_stroma[" pearsonOutsideStromaKer"], df_stroma["FN_568"], color='lightgreen', label='Outside KER_488', s=20, marker='*')
axs[1, 1].scatter(df_stroma[" pearsonInsideStromaKer"], df_stroma["FN_568"], color='darkgreen', label='Inside KER_488', s=20, marker='^')
#axs[1, 1].axvline(x=0, ls='--', color='black')

axs[1, 0].scatter(df_stroma[" pearsonInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Inside KER_488: pNDRG1_647', s=20, marker='^')
axs[1, 0].scatter(df_stroma[" pearsonOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='lightblue', label='Outside KER_488: pNDRG1_647', s=20, marker='*')
#axs[1, 0].axvline(x=0, ls='--', color='black')

# Adjust the position of subplots to add space between rows
#axs[0, 0].set_position([axs[0, 0].get_position().x0, axs[0, 0].get_position().y0 - 0.03, axs[0, 0].get_position().width, axs[0, 0].get_position().height])
#axs[0, 1].set_position([axs[0, 1].get_position().x0, axs[0, 1].get_position().y0 - 0.03, axs[0, 1].get_position().width, axs[0, 1].get_position().height])

# Set common labels
fig.text(0.5, -0.03, 'Pearson Correlation Coefficient', ha='center', va='center', fontsize=15)
fig.text(-0.01, 0.78, r'Smoothing sigma $\sigma$', ha='center', va='center', rotation='vertical', fontsize=15)
fig.text(-0.01, 0.23, 'FN_568 intensity', ha='center', va='center', rotation='vertical', fontsize=15)

plt.tight_layout()
plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240222_plots/20240301_pearson_sensitivity_stroma_annotation.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
from scipy.stats import ttest_ind

# Select the data for the two groups
inside_KER488 = df_stroma[" pearsonInsideStromaKer"]
print(np.mean(inside_KER488))
inside_KER488_pNDRG1_647 = df_stroma[" pearsonInsideStromaKerPNDRG1"]
print(np.mean(inside_KER488_pNDRG1_647))
# Select the data for the two groups
outside_KER488 = df_stroma[" pearsonOutsideStromaKer"]
print(np.mean(outside_KER488))
outside_KER488_pNDRG1_647 = df_stroma[" pearsonOutsideStromaKerPNDRG1"]
print(np.mean(outside_KER488_pNDRG1_647))

# Perform the t-test
t_statistic, p_value = ttest_ind(inside_KER488, inside_KER488_pNDRG1_647)
# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488 and Inside KER_488: pNDRG1_647: {:.2e}".format(p_value))

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488, outside_KER488_pNDRG1_647)

# Print the p-value
print("P-value for the difference in correlation coefficients between Outside KER_488 and Outside KER_488: pNDRG1_647: {:.2e}".format(p_value))

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488, inside_KER488)

# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488 and Outside KER_488: {:.2e}".format(p_value))

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488_pNDRG1_647, inside_KER488_pNDRG1_647)

# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488: pNDRG1_647 and Outside KER_488: pNDRG1_647: {:.2e}".format(p_value))
# Out:
# 0.01688180548359219
# 0.08496403808870352
# -0.12566122108763392
# -0.08760704182874546
# P-value for the difference in correlation coefficients between Inside KER_488 and Inside KER_488: pNDRG1_647: 1.96e-114
# P-value for the difference in correlation coefficients between Outside KER_488 and Outside KER_488: pNDRG1_647: 4.48e-49
# P-value for the difference in correlation coefficients between Inside KER_488 and Outside KER_488: 0.00e+00
# P-value for the difference in correlation coefficients between Inside KER_488: pNDRG1_647 and Outside KER_488: pNDRG1_647: 0.00e+00

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Path to the folder containing CSV files
folder_path = '/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240229_correlations/'

# Initialize an empty list to store DataFrames
dfs = []

# Iterate over files in the folder
for file in os.listdir(folder_path):
    if file.endswith('.csv'):
        # Read CSV file and append to the list
        df = pd.read_csv(os.path.join(folder_path, file))
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
df_stroma = pd.concat(dfs, ignore_index=True)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 15), sharex=True)

# Plot data on each subplot
axs[0, 0].scatter(df_stroma[" spearmanInsideStromaKer"], df_stroma[" sigma"], color='lightblue', label='Outside KER_488: pNDRG1_647', s=20, marker='*')
axs[0, 0].scatter(df_stroma[" spearmanInsideStromaKerPNDRG1"], df_stroma[" sigma"], color='darkblue', label='Inside KER_488: pNDRG1_647', s=20, marker='^')
#axs[0, 0].axvline(x=0, ls='--', color='black')
axs[0, 0].legend(fontsize='large', loc='upper left')

axs[0, 1].scatter(df_stroma[" spearmanOutsideStromaKer"], df_stroma[" sigma"], color='lightgreen', label='Outside KER_488', s=20, marker='*')
axs[0, 1].scatter(df_stroma[" spearmanInsideStromaKer"], df_stroma[" sigma"], color='darkgreen', label='Inside KER_488', s=20, marker='^')
#axs[0, 1].axvline(x=0, ls='--', color='black')
axs[0, 1].legend(fontsize='large', loc='upper right')

axs[1, 1].scatter(df_stroma[" spearmanOutsideStromaKer"], df_stroma["FN_568"], color='lightgreen', label='Outside KER_488', s=20, marker='*')
axs[1, 1].scatter(df_stroma[" spearmanInsideStromaKer"], df_stroma["FN_568"], color='darkgreen', label='Inside KER_488', s=20, marker='^')
#axs[1, 1].axvline(x=0, ls='--', color='black')

axs[1, 0].scatter(df_stroma[" spearmanInsideStromaKerPNDRG1"], df_stroma["FN_568"], color='darkblue', label='Inside KER_488: pNDRG1_647', s=20, marker='^')
axs[1, 0].scatter(df_stroma[" spearmanOutsideStromaKerPNDRG1"], df_stroma["FN_568"], color='lightblue', label='Outside KER_488: pNDRG1_647', s=20, marker='*')
#axs[1, 0].axvline(x=0, ls='--', color='black')

# Adjust the position of subplots to add space between rows
#axs[0, 0].set_position([axs[0, 0].get_position().x0, axs[0, 0].get_position().y0 - 0.0, axs[0, 0].get_position().width, axs[0, 0].get_position().height])
#axs[0, 1].set_position([axs[0, 1].get_position().x0, axs[0, 1].get_position().y0 - 0.03, axs[0, 1].get_position().width, axs[0, 1].get_position().height])

# Set common labels
fig.text(0.5, -0.03, 'Spearman Correlation Coefficient', ha='center', va='center', fontsize=15)
fig.text(-0.01, 0.78, r'Smoothing sigma $\sigma$', ha='center', va='center', rotation='vertical', fontsize=15)
fig.text(-0.01, 0.23, 'FN_568 intensity', ha='center', va='center', rotation='vertical', fontsize=15)

plt.tight_layout()
plt.savefig('/Users/antoine/Harvard/IAC/NinaKozlova/20240111_AsPC_pNDRG1/Results/20240222_plots/20240301_spearman_sensitivity_stroma_annotation.png', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
from scipy.stats import ttest_ind

# Select the data for the two groups
inside_KER488 = df_stroma[" spearmanInsideStromaKer"]
inside_KER488_pNDRG1_647 = df_stroma[" spearmanInsideStromaKerPNDRG1"]
# Select the data for the two groups
outside_KER488 = df_stroma[" spearmanOutsideStromaKer"]
outside_KER488_pNDRG1_647 = df_stroma[" spearmanOutsideStromaKerPNDRG1"]

# Perform the t-test
t_statistic, p_value = ttest_ind(inside_KER488, inside_KER488_pNDRG1_647)
# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488 and Inside KER_488: pNDRG1_647: {:.2e}".format(p_value))

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488, outside_KER488_pNDRG1_647)

# Print the p-value
print("P-value for the difference in correlation coefficients between Outside KER_488 and Outside KER_488: pNDRG1_647: {:.2e}".format(p_value))

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488, inside_KER488)

# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488 and Outside KER_488: {:.2e}".format(p_value))

# Perform the t-test
t_statistic, p_value = ttest_ind(outside_KER488_pNDRG1_647, inside_KER488_pNDRG1_647)

# Print the p-value
print("P-value for the difference in correlation coefficients between Inside KER_488: pNDRG1_647 and Outside KER_488: pNDRG1_647: {:.2e}".format(p_value))
# Out:
# P-value for the difference in correlation coefficients between Inside KER_488 and Inside KER_488: pNDRG1_647: 5.78e-250
# P-value for the difference in correlation coefficients between Outside KER_488 and Outside KER_488: pNDRG1_647: 1.40e-57
# P-value for the difference in correlation coefficients between Inside KER_488 and Outside KER_488: 0.00e+00
# P-value for the difference in correlation coefficients between Inside KER_488: pNDRG1_647 and Outside KER_488: pNDRG1_647: 0.00e+00
